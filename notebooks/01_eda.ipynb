# %%
print("Hello Foundry AI!")
# Out:
# Running cells with 'Python 3.13.3' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/Srushti/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import sys

print(sys.executable)
# Out:
# c:\Users\Srushti\Desktop\Foundry quality intelligence\venv\Scripts\python.exe

# %%
import numpy as np
import pandas as pd
import sklearn

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
print("ML environment is ready! 🚀")
# Out:
# NumPy: 2.5.3
# Pandas: 3.0.6
# Scikit-learn: 1.9.1
# ML environment is ready! 🚀
